# %%
import pandas as pd
import sqlite3
import numpy as np
import zipfile

# %%
with zipfile.ZipFile("im.db.zip", "r") as zip_ref:
    zip_ref.extractall("unzipped_files")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-60568094d586> in <module>
# ----> 1 with zipfile.ZipFile("im.db.zip", "r") as zip_ref:
#       2     zip_ref.extractall("unzipped_files")
#
# c:\Users\hp\anaconda3\envs\learn-env\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1249             while True:
#    1250                 try:
# -> 1251                     self.fp = io.open(file, filemode)
#    1252                 except OSError:
#    1253                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'im.db.zip'
